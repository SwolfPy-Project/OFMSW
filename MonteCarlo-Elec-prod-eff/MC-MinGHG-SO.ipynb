# %% [markdown]
# # Monte Carlo -  MinGHG-SO

# %%
import swolfpy as sp
import swolfpy_inputdata as spid
import swolfpy_processmodels as sppm

import brightway2 as bw2
import pandas as pd
import numpy as np
from scipy import stats
from time import time
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import os
import platform
from IPython.display import Image

# Set font for plots
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "14"

# Set specs for pandas
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 700)
pd.set_option("precision", 2)

# %% [markdown]
# ### SwolfPy version used to produced the results:

# %%
pd.DataFrame({'Version': [sp.__version__, sppm.__version__, spid.__version__]},
             index=['swolfpy', 'swolfpy_processmodels', 'swolfpy_inputdata'])
# Out:
#                       Version
# swolfpy                0.2.4
# swolfpy_processmodels  0.1.9
# swolfpy_inputdata      0.2.4

# %% [markdown]
# ### System info

# %%
pd.DataFrame({'info': [platform.platform(),
                       platform.processor(),
                       os.cpu_count()]},
             index=['Platform', 'Processor', 'CPU_count'])
# Out:
#                                                           info
# Platform   Windows-10-10.0.19041-SP0
# Processor  Intel64 Family 6 Model 158 Stepping 9, GenuineIntel
# CPU_count  8

# %%
MC_Name = 'MC MinGHG-SO'

n_iter = 5000
n_proc = os.cpu_count()

method = ('SwolfPy_Total_Cost', 'SwolfPy')

TotCost_Method = ('SwolfPy_Total_Cost', 'SwolfPy')
OptCost_Method = ('SwolfPy_Operational_Cost', 'SwolfPy')
CapCost_Method = ('SwolfPy_Capital_Cost', 'SwolfPy')
GWP_Method = ('IPCC 2013, Ecoinvent V3.5', 'climate change', 'GWP 100a, bioCO2=1, C1_36')
CED_Method = ('cumulative energy demand', 'fossil', 'non-renewable energy resources, fossil')
ACID_Method = ('TRACI (2.1) SwolfPy', 'environmental impact', 'acidification')
ETP_Method = ('TRACI (2.1) SwolfPy', 'environmental impact', 'eutrophication')
SMOG_Method = ('TRACI (2.1) SwolfPy', 'environmental impact', 'photochemical smog')
ETOX_Method = ('USEtox (obsolete)', 'ecotoxicity', 'total')
HTOX_Method = ('USEtox (obsolete)', 'human toxicity', 'total')

# %% [markdown]
# ## Create project

# %%
project_name = 'MonteCarlo'
technosphere = sp.Technosphere(project_name)
common_data = spid.CommonData()
ProcessMetaData = sppm.ProcessModelsMetaData.ProcessModelsMetaData

# %%
# Treatment processes
Treatment_processes = {}
Treatment_processes['LF'] = {'input_type':ProcessMetaData['LF']['InputType'] , 'model':sppm.LF()}
Treatment_processes['Composting'] = {'input_type':ProcessMetaData['Comp']['InputType'] , 'model':sppm.Comp()}
Treatment_processes['HC'] = {'input_type':ProcessMetaData['HC']['InputType'] , 'model':sppm.HC()}
Treatment_processes['AD'] = {'input_type':ProcessMetaData['AD']['InputType'] , 'model':sppm.AD()}
Treatment_processes['AnF'] = {'input_type':ProcessMetaData['AnF']['InputType'] , 'model':sppm.AnF()}
Treatment_processes['SS_MRF'] = {'input_type':ProcessMetaData['SS_MRF']['InputType'] , 'model':sppm.SS_MRF()}
Treatment_processes['Reprocessing'] = {'input_type':ProcessMetaData['Reproc']['InputType'] , 'model':sppm.Reproc()}
Treatment_processes['RDF'] = {'input_type':ProcessMetaData['RDF']['InputType'] , 'model':sppm.RDF()}
Treatment_processes['GC'] = {'input_type':ProcessMetaData['GC']['InputType'] , 'model':sppm.GC()}
Treatment_processes['WTE'] = {'input_type':ProcessMetaData['WTE']['InputType'] , 'model':sppm.WTE()}

# %%
# Distance
Processes = ['LF', 'Composting', 'HC', 'AD', 'AnF', 'SS_MRF', 'Reprocessing', 'RDF', 'GC', 'WTE', 'SF', 'MF', 'COM']
data = sppm.Distance.create_distance_table(process_names=Processes,
                                           transport_modes=['Heavy Duty Truck'],
                                           default_dist=30)

distance = sppm.Distance(data)          
data['Heavy Duty Truck']
# Out:
#               LF  Composting    HC    AD   AnF  SS_MRF  Reprocessing   RDF  \
# LF           NaN  30.0        30.0  30.0  30.0  30.0    30.0          30.0
# Composting   NaN NaN          30.0  30.0  30.0  30.0    30.0          30.0
# HC           NaN NaN         NaN    30.0  30.0  30.0    30.0          30.0
# AD           NaN NaN         NaN   NaN    30.0  30.0    30.0          30.0
# AnF          NaN NaN         NaN   NaN   NaN    30.0    30.0          30.0
# SS_MRF       NaN NaN         NaN   NaN   NaN   NaN      30.0          30.0
# Reprocessing NaN NaN         NaN   NaN   NaN   NaN     NaN            30.0
# RDF          NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
# GC           NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
# WTE          NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
# SF           NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
# MF           NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
# COM          NaN NaN         NaN   NaN   NaN   NaN     NaN           NaN
#
#                 GC   WTE    SF    MF   COM
# LF            30.0  30.0  30.0  30.0  30.0
# Composting    30.0  30.0  30.0  30.0  30.0
# HC            30.0  30.0  30.0  30.0  30.0
# AD            30.0  30.0  30.0  30.0  30.0
# AnF           30.0  30.0  30.0  30.0  30.0
# SS_MRF        30.0  30.0  30.0  30.0  30.0
# Reprocessing  30.0  30.0  30.0  30.0  30.0
# RDF           30.0  30.0  30.0  30.0  30.0
# GC           NaN    30.0  30.0  30.0  30.0
# WTE          NaN   NaN    30.0  30.0  30.0
# SF           NaN   NaN   NaN    30.0  30.0
# MF           NaN   NaN   NaN   NaN    30.0
# COM          NaN   NaN   NaN   NaN   NaN

# %%
# Collection_processes:
Collection_processes = {}

SF_scheme = sppm.SF_Col.scheme()
SF_scheme[('RWC', 'SSO', 'SSR')] = 1
Collection_processes['SF'] = {'input_type': [],
                              'model': sppm.SF_Col('SF', SF_scheme,
                              Treatment_processes=Treatment_processes,
                              Distance=distance)}

MF_scheme = sppm.MF_Col.scheme()
MF_scheme[('RWC', 'SSO', 'SSR')] = 1
Collection_processes['MF'] = {'input_type': [],
                              'model': sppm.MF_Col('MF', MF_scheme,
                              Treatment_processes=Treatment_processes,
                              Distance=distance)}

COM_scheme = sppm.COM_Col.scheme()
COM_scheme[('RWC', 'SSO_AnF', 'SSR')] = 1
Collection_processes['COM'] = {'input_type': [],
                               'model': sppm.COM_Col('COM', COM_scheme,
                               Treatment_processes=Treatment_processes,
                               Distance=distance)}

# %%
population = 10**6
SF_density = 2.66
MF_density = 2.06
MF_fraction = 0.25
res_gen_rate = 1.12

# Composition data
comp_data = pd.read_csv('Composition Data/Updated Composition.csv', index_col=0)

# Set SF
Collection_processes['SF']['model'].process_data['Comp'] = comp_data['SingleFamily'].values
Collection_processes['SF']['model'].InputData.Col['res_per_dwel']['amount'] = SF_density
Collection_processes['SF']['model'].InputData.Col['houses_res']['amount'] = population * (1-MF_fraction) / SF_density
Collection_processes['SF']['model'].InputData.Col['res_gen']['amount'] = res_gen_rate

# Set MF
Collection_processes['MF']['model'].process_data['Comp'] = comp_data['MultiFamily'].values
Collection_processes['MF']['model'].InputData.Col['res_per_dwel']['amount'] = MF_density
Collection_processes['MF']['model'].InputData.Col['houses_res']['amount'] = population * MF_fraction / MF_density
Collection_processes['MF']['model'].InputData.Col['res_gen']['amount'] = res_gen_rate

# Set COM
Collection_processes['COM']['model'].process_data['Comp'] = comp_data['Restaurants'].values
Mass_Restaurants = 0.0549 * population - 2304.8
N_locations = 1000
Collection_processes['COM']['model'].InputData.Col['comm_gen']['amount'] = Mass_Restaurants / N_locations / (365/7) * 1000
Collection_processes['COM']['model'].InputData.Col['comm_loc']['amount'] = N_locations

# %% [markdown]
# ## Set RDF composition in GC

# %%
RDF_Comp = pd.read_csv('RDF_comp/MinGHG_SO_RDF_Comp.csv', index_col=0)
Treatment_processes['GC']['model'].process_data['Assumed_Comp']  = RDF_Comp['New RDF Comp']

# %% [markdown]
# ## Define Uncertainty

# %%
from Set_MC_Elec import Set_MC
Set_MC(Treatment_processes, Collection_processes, common_data)

# %%
start = time()
demo = sp.Project(project_name, common_data, Treatment_processes, distance, Collection_processes, technosphere)
demo.init_project()
demo.write_project()
demo.group_exchanges()
print("Time for writing the project: {} second".format(round(time()-start)))
# Out:
# Biosphere database already present!!! No setup is needed
# Vacuuming database
# Vacuuming database
# Vacuuming database
# Writing activities to SQLite3 database:
#                 ####
#                 ++++++  Writing the Technosphere
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:15
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:12
#   Finished: 02/26/2022 00:04:28
#   Total time elapsed: 00:00:15
#   CPU %: 46.80
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the LF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 97.70
#   Memory %: 1.39
#
#               ####
#               ++++++ Initializing the Composting
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 104.20
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the HC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 97.70
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the AD
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 151.20
#   Memory %: 1.39
#
#               ####
#               ++++++ Initializing the AnF
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 100.80
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the SS_MRF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 100.80
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the Reprocessing
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:29
#   Finished: 02/26/2022 00:04:29
#   Total time elapsed: 00:00:00
#   CPU %: 104.20
#   Memory %: 1.39
#
#               ####
#               ++++++ Initializing the RDF
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 104.20
#   Memory %: 1.39
#
#               ####
#               ++++++ Initializing the GC
# Writing activities to SQLite3 database:
# 0% [#] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 1.39
#
#               ####
#               ++++++ Initializing the WTE
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 195.30
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the SF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 97.70
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the MF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 100.80
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Initializing the COM
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:30
#   Total time elapsed: 00:00:00
#   CPU %: 97.70
#   Memory %: 1.39
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the LF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:30
#   Finished: 02/26/2022 00:04:31
#   Total time elapsed: 00:00:01
#   CPU %: 61.00
#   Memory %: 1.41
#
#                   ####
#                   ++++++ Writing the Composting_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:32
#   Finished: 02/26/2022 00:04:32
#   Total time elapsed: 00:00:00
#   CPU %: 100.80
#   Memory %: 1.42
#
#               ####
#               ++++++ Writing the Composting
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:32
#   Finished: 02/26/2022 00:04:32
#   Total time elapsed: 00:00:00
#   CPU %: 68.80
#   Memory %: 1.42
#
#               ####
#               ++++++ Writing the HC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:32
#   Finished: 02/26/2022 00:04:32
#   Total time elapsed: 00:00:00
#   CPU %: 72.70
#   Memory %: 1.43
#
#                   ####
#                   ++++++ Writing the AD_product
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:32
#   Finished: 02/26/2022 00:04:33
#   Total time elapsed: 00:00:00
#   CPU %: 99.70
#   Memory %: 1.43
#
#               ####
#               ++++++ Writing the AD
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:33
#   Finished: 02/26/2022 00:04:33
#   Total time elapsed: 00:00:00
#   CPU %: 75.90
#   Memory %: 1.43
#
#                   ####
#                   ++++++ Writing the AnF_product
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:33
#   Finished: 02/26/2022 00:04:33
#   Total time elapsed: 00:00:00
#   CPU %: 99.70
#   Memory %: 1.44
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the AnF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:33
#   Finished: 02/26/2022 00:04:33
#   Total time elapsed: 00:00:00
#   CPU %: 120.20
#   Memory %: 1.44
#
#                   ####
#                   ++++++ Writing the SS_MRF_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:34
#   Finished: 02/26/2022 00:04:34
#   Total time elapsed: 00:00:00
#   CPU %: 50.00
#   Memory %: 1.45
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the SS_MRF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Writing activities to SQLite3 database:
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:35
#   Finished: 02/26/2022 00:04:35
#   Total time elapsed: 00:00:00
#   CPU %: 90.10
#   Memory %: 1.46
#
#               ####
#               ++++++ Writing the Reprocessing
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:35
#   Finished: 02/26/2022 00:04:35
#   Total time elapsed: 00:00:00
#   CPU %: 49.90
#   Memory %: 1.47
#
#                   ####
#                   ++++++ Writing the RDF_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:36
#   Finished: 02/26/2022 00:04:36
#   Total time elapsed: 00:00:00
#   CPU %: 83.10
#   Memory %: 1.47
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the RDF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:36
#   Finished: 02/26/2022 00:04:36
#   Total time elapsed: 00:00:00
#   CPU %: 120.20
#   Memory %: 1.47
# Writing activities to SQLite3 database:
#                   ####
#                   ++++++ Writing the GC_product
# 0% [#############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:37
#   Finished: 02/26/2022 00:04:37
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 1.47
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the GC
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:37
#   Finished: 02/26/2022 00:04:37
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 1.47
#
#                   ####
#                   ++++++ Writing the WTE_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:37
#   Finished: 02/26/2022 00:04:37
#   Total time elapsed: 00:00:00
#   CPU %: 79.10
#   Memory %: 1.47
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the WTE
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:38
#   Finished: 02/26/2022 00:04:38
#   Total time elapsed: 00:00:00
#   CPU %: 73.70
#   Memory %: 1.47
#
#                   ####
#                   ++++++ Writing the SF_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:38
#   Finished: 02/26/2022 00:04:39
#   Total time elapsed: 00:00:00
#   CPU %: 63.10
#   Memory %: 1.49
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the SF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:40
#   Finished: 02/26/2022 00:04:40
#   Total time elapsed: 00:00:00
#   CPU %: 83.10
#   Memory %: 1.50
#
#                   ####
#                   ++++++ Writing the MF_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:40
#   Finished: 02/26/2022 00:04:40
#   Total time elapsed: 00:00:00
#   CPU %: 79.60
#   Memory %: 1.50
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the MF
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:41
#   Finished: 02/26/2022 00:04:41
#   Total time elapsed: 00:00:00
#   CPU %: 83.10
#   Memory %: 1.50
#
#                   ####
#                   ++++++ Writing the COM_product
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:41
#   Finished: 02/26/2022 00:04:42
#   Total time elapsed: 00:00:00
#   CPU %: 50.10
#   Memory %: 1.51
# Writing activities to SQLite3 database:
#               ####
#               ++++++ Writing the COM
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/26/2022 00:04:42
#   Finished: 02/26/2022 00:04:42
#   Total time elapsed: 00:00:00
#   CPU %: 80.10
#   Memory %: 1.51
#
#                   Grouping the exchanges with parameters in Database LF
#
#
#                   Grouping the exchanges with parameters in Database Composting
#
#
#                   Grouping the exchanges with parameters in Database HC
#
#
#                   Grouping the exchanges with parameters in Database AD
#
#
#                   Grouping the exchanges with parameters in Database AnF
#
#
#                   Grouping the exchanges with parameters in Database SS_MRF
#
#
#                   Grouping the exchanges with parameters in Database Reprocessing
#
#
#                   Grouping the exchanges with parameters in Database RDF
#
#
#                   Grouping the exchanges with parameters in Database GC
#
#
#                   Grouping the exchanges with parameters in Database WTE
#
#
#                   Grouping the exchanges with parameters in Database SF
#
#
#                   Grouping the exchanges with parameters in Database MF
#
#
#                   Grouping the exchanges with parameters in Database COM
#
# Time for writing the project: 140 second

# %%
prms = [
    {'name': 'frac_of_Other_Residual_from_Composting_to_LF', 'amount': 0},
    {'name': 'frac_of_Other_Residual_from_Composting_to_WTE', 'amount': 1},
    {'name': 'frac_of_Other_Residual_from_AD_to_LF', 'amount': 0},
    {'name': 'frac_of_Other_Residual_from_AD_to_WTE', 'amount': 1},
    {'name': 'frac_of_Other_Residual_from_AnF_to_LF', 'amount': 0},
    {'name': 'frac_of_Other_Residual_from_AnF_to_WTE', 'amount': 1},
    {'name': 'frac_of_Other_Residual_from_SS_MRF_to_LF', 'amount': 0},
    {'name': 'frac_of_Other_Residual_from_SS_MRF_to_WTE', 'amount': 1},
    {'name': 'frac_of_Separated_Organics_from_RDF_to_Composting', 'amount': 0},
    {'name': 'frac_of_Separated_Organics_from_RDF_to_AD', 'amount': 1},
    {'name': 'frac_of_Other_Residual_from_RDF_to_LF', 'amount': 0},
    {'name': 'frac_of_Other_Residual_from_RDF_to_WTE', 'amount': 1},
    {'name': 'frac_of_RWC_from_SF_to_LF', 'amount': 0},
    {'name': 'frac_of_RWC_from_SF_to_RDF', 'amount': 1},
    {'name': 'frac_of_RWC_from_SF_to_WTE', 'amount': 0},
    {'name': 'frac_of_SSO_from_SF_to_Composting', 'amount': 0},
    {'name': 'frac_of_SSO_from_SF_to_AD', 'amount': 1},
    {'name': 'frac_of_MRDO_from_SF_to_LF', 'amount': 1},
    {'name': 'frac_of_MRDO_from_SF_to_RDF', 'amount': 0},
    {'name': 'frac_of_MRDO_from_SF_to_WTE', 'amount': 0},
    {'name': 'frac_of_RWC_from_MF_to_LF', 'amount': 0},
    {'name': 'frac_of_RWC_from_MF_to_RDF', 'amount': 1},
    {'name': 'frac_of_RWC_from_MF_to_WTE', 'amount': 0},
    {'name': 'frac_of_SSO_from_MF_to_Composting', 'amount': 0},
    {'name': 'frac_of_SSO_from_MF_to_AD', 'amount': 1},
    {'name': 'frac_of_RWC_from_COM_to_LF', 'amount': 0},
    {'name': 'frac_of_RWC_from_COM_to_RDF', 'amount': 1},
    {'name': 'frac_of_RWC_from_COM_to_WTE', 'amount': 0},
    {'name': 'frac_of_SSO_from_COM_to_Composting', 'amount': 0},
    {'name': 'frac_of_SSO_from_COM_to_AD', 'amount': 1}]

# %%
start = time()
demo.update_parameters(prms)
print("Time for updating the parameters: {} second".format(round(time()-start)))
demo.parameters_list
# Out:
# Time for updating the parameters: 22 second
# [{'name': 'frac_of_Other_Residual_from_Composting_to_LF', 'amount': 0},
#  {'name': 'frac_of_Other_Residual_from_Composting_to_WTE', 'amount': 1},
#  {'name': 'frac_of_Other_Residual_from_AD_to_LF', 'amount': 0},
#  {'name': 'frac_of_Other_Residual_from_AD_to_WTE', 'amount': 1},
#  {'name': 'frac_of_Other_Residual_from_AnF_to_LF', 'amount': 0},
#  {'name': 'frac_of_Other_Residual_from_AnF_to_WTE', 'amount': 1},
#  {'name': 'frac_of_Other_Residual_from_SS_MRF_to_LF', 'amount': 0},
#  {'name': 'frac_of_Other_Residual_from_SS_MRF_to_WTE', 'amount': 1},
#  {'name': 'frac_of_Separated_Organics_from_RDF_to_Composting', 'amount': 0},
#  {'name': 'frac_of_Separated_Organics_from_RDF_to_AD', 'amount': 1},
#  {'name': 'frac_of_Other_Residual_from_RDF_to_LF', 'amount': 0},
#  {'name': 'frac_of_Other_Residual_from_RDF_to_WTE', 'amount': 1},
#  {'name': 'frac_of_RWC_from_SF_to_LF', 'amount': 0},
#  {'name': 'frac_of_RWC_from_SF_to_RDF', 'amount': 1},
#  {'name': 'frac_of_RWC_from_SF_to_WTE', 'amount': 0},
#  {'name': 'frac_of_SSO_from_SF_to_Composting', 'amount': 0},
#  {'name': 'frac_of_SSO_from_SF_to_AD', 'amount': 1},
#  {'name': 'frac_of_MRDO_from_SF_to_LF', 'amount': 1},
#  {'name': 'frac_of_MRDO_from_SF_to_RDF', 'amount': 0},
#  {'name': 'frac_of_MRDO_from_SF_to_WTE', 'amount': 0},
#  {'name': 'frac_of_RWC_from_MF_to_LF', 'amount': 0},
#  {'name': 'frac_of_RWC_from_MF_to_RDF', 'amount': 1},
#  {'name': 'frac_of_RWC_from_MF_to_WTE', 'amount': 0},
#  {'name': 'frac_of_SSO_from_MF_to_Composting', 'amount': 0},
#  {'name': 'frac_of_SSO_from_MF_to_AD', 'amount': 1},
#  {'name': 'frac_of_RWC_from_COM_to_LF', 'amount': 0},
#  {'name': 'frac_of_RWC_from_COM_to_RDF', 'amount': 1},
#  {'name': 'frac_of_RWC_from_COM_to_WTE', 'amount': 0},
#  {'name': 'frac_of_SSO_from_COM_to_Composting', 'amount': 0},
#  {'name': 'frac_of_SSO_from_COM_to_AD', 'amount': 1}]

# %%
params_df = pd.DataFrame(demo.parameters_list)
for i, j in params_df['name'].items():
    if type(j) == str:
        j = j.strip('frac_of_')
        params_df.loc[i, 'From'] = j.split('_from_')[1].split('_to_')[0]
        params_df.loc[i, 'To'] = j.split('_from_')[1].split('_to_')[1]
        params_df.loc[i, 'Product'] = j.split('_from_')[0]
    else:
        params_df.loc[i, 'From'] = j[0]
        params_df.loc[i, 'Product'] = str(j[1])
params_df[['From', 'To', 'Product', 'amount']]
# Out:
#           From          To             Product  amount
# 0   Composting  LF          Other_Residual      0
# 1   Composting  WTE         Other_Residual      1
# 2   AD          LF          Other_Residual      0
# 3   AD          WTE         Other_Residual      1
# 4   AnF         LF          Other_Residual      0
# 5   AnF         WTE         Other_Residual      1
# 6   SS_MRF      LF          Other_Residual      0
# 7   SS_MRF      WTE         Other_Residual      1
# 8   RDF         Composting  Separated_Organics  0
# 9   RDF         AD          Separated_Organics  1
# 10  RDF         LF          Other_Residual      0
# 11  RDF         WTE         Other_Residual      1
# 12  SF          LF          RWC                 0
# 13  SF          RDF         RWC                 1
# 14  SF          WTE         RWC                 0
# 15  SF          Composting  SSO                 0
# 16  SF          AD          SSO                 1
# 17  SF          LF          MRDO                1
# 18  SF          RDF         MRDO                0
# 19  SF          WTE         MRDO                0
# 20  MF          LF          RWC                 0
# 21  MF          RDF         RWC                 1
# 22  MF          WTE         RWC                 0
# 23  MF          Composting  SSO                 0
# 24  MF          AD          SSO                 1
# 25  COM         LF          RWC                 0
# 26  COM         RDF         RWC                 1
# 27  COM         WTE         RWC                 0
# 28  COM         Composting  SSO                 0
# 29  COM         AD          SSO                 1

# %%
input_dict = {'SF':{}, 'MF':{}, 'COM':{}}

for key in common_data.Index:
    input_dict['SF'][key] = 1
    input_dict['MF'][key] = 1
    input_dict['COM'][key] = 1

demo.create_scenario(input_dict, 'Collection')

# %% [markdown]
# ## Mass flows, impacts and costs based on default parameters

# %%
process_list = ['SF', 'MF', 'COM', 'LF', 'WTE', 'RDF', 'GC', 'Composting', 'AD', 'HC', 'AnF', 'SS_MRF', 'Reprocessing']
perform_index = ['Diversion', 'GWP', 'Operation Cost', 'Capital cost', 'Total cost',
                 'CED', 'Acidification', 'Eutrophication', 'Photochemical smog',
                 'Ecotoxicity', 'Human toxicity']
results = pd.DataFrame(columns=['Value', 'Unit'],
                       index=perform_index+process_list,)

bw2.projects.set_current(project_name)
Demand = {('waste', 'Collection'):1}
FU=bw2.get_activity(('waste', 'Collection'))
lca=bw2.LCA(Demand, GWP_Method)
lca.lci()
lca.lcia()
results.loc['GWP',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'kg CO2 eq/Mg']

lca.switch_method(OptCost_Method)
lca.lcia()
results.loc['Operation Cost',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), '$/Mg']


lca.switch_method(CapCost_Method)
lca.lcia()
results.loc['Capital cost',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), '$/Mg']

lca.switch_method(TotCost_Method)
lca.lcia()
results.loc['Total cost',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), '$/Mg']

lca.switch_method(CED_Method)
lca.lcia()
results.loc['CED',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'MJ eq/Mg']

lca.switch_method(ACID_Method)
lca.lcia()
results.loc['Acidification',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'kg SO2 eq/Mg']

lca.switch_method(ETP_Method)
lca.lcia()
results.loc['Eutrophication',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'kg N eq/Mg']

lca.switch_method(SMOG_Method)
lca.lcia()
results.loc['Photochemical smog',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'kg O3 eq/Mg']

lca.switch_method(ETOX_Method)
lca.lcia()
results.loc['Ecotoxicity',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'CTU/Mg']

lca.switch_method(HTOX_Method)
lca.lcia()
results.loc['Human toxicity',:] = [lca.score/float(FU.as_dict()['unit'].split(' ')[0]), 'CTU/Mg']


for process in process_list:
    results.loc[process,:] = [round(sp.LCA_matrix.LCA_matrix.get_mass_flow(lca, process)), 'Mg/yr']

results.loc['Diversion',:] = [(1 - results['Value']['LF'] / float(FU.as_dict()['unit'].split(' ')[0])) * 100, '%']
results.to_csv(f'{MC_Name}.csv')
results
# Out:
#                       Value          Unit
# Diversion           87.61    %
# GWP                 180.52   kg CO2 eq/Mg
# Operation Cost      58.25    $/Mg
# Capital cost        39.47    $/Mg
# Total cost          97.72    $/Mg
# CED                -8215.82  MJ eq/Mg
# Acidification      -4.58     kg SO2 eq/Mg
# Eutrophication     -0.92     kg N eq/Mg
# Photochemical smog -8.5      kg O3 eq/Mg
# Ecotoxicity        -5574.34  CTU/Mg
# Human toxicity     -0.0      CTU/Mg
# SF                  306600   Mg/yr
# MF                  102200   Mg/yr
# COM                 52595    Mg/yr
# LF                  57147    Mg/yr
# WTE                 64323    Mg/yr
# RDF                 225008   Mg/yr
# GC                  178354   Mg/yr
# Composting          0        Mg/yr
# AD                  101413   Mg/yr
# HC                  0        Mg/yr
# AnF                 19969    Mg/yr
# SS_MRF              115005   Mg/yr
# Reprocessing        105244   Mg/yr

# %% [markdown]
# ## Monte Carlo simulation

# %%
process_models = []
process_model_names = []

methods = [TotCost_Method, OptCost_Method, CapCost_Method, GWP_Method,
           CED_Method, ACID_Method, ETP_Method, SMOG_Method, ETOX_Method,
           HTOX_Method]

for P in demo.Treatment_processes:
    process_models.append(demo.Treatment_processes[P]['model'])
    process_model_names.append(P)

mc = sp.Monte_Carlo(functional_unit=Demand,
                    method=methods,
                    project=demo.project_name,
                    process_models=process_models,
                    process_model_names= process_model_names,
                    seed=0)
start = time()
mc.run(n_proc, n_iter)
print(f"time = {round((time()-start)/60, 1)} min")
# Out:
# time = 11.0 min

# %%
mc_results=mc.result_to_DF()
mc_results.to_pickle(f'{MC_Name} results.pickle')
mc_results.head()
# Out:
#    (SwolfPy_Total_Cost, SwolfPy)  (SwolfPy_Operational_Cost, SwolfPy)  \
# 0  4.45e+07                       2.52e+07
# 1  4.83e+07                       3.23e+07
# 2  5.94e+07                       3.52e+07
# 3  3.66e+07                       1.91e+07
# 4  4.36e+07                       2.33e+07
#
#    (SwolfPy_Capital_Cost, SwolfPy)  \
# 0  1.93e+07
# 1  1.61e+07
# 2  2.42e+07
# 3  1.75e+07
# 4  2.03e+07
#
#    (IPCC 2013, Ecoinvent V3.5, climate change, GWP 100a, bioCO2=1, C1_36)  \
# 0  9.46e+07
# 1  8.29e+07
# 2  1.88e+08
# 3  4.44e+07
# 4  3.66e+07
#
#    (cumulative energy demand, fossil, non-renewable energy resources, fossil)  \
# 0 -3.66e+09
# 1 -3.81e+09
# 2 -2.55e+09
# 3 -4.28e+09
# 4 -4.35e+09
#
#    (TRACI (2.1) SwolfPy, environmental impact, acidification)  \
# 0 -2.04e+06
# 1 -2.11e+06
# 2 -1.43e+06
# 3 -2.36e+06
# 4 -2.41e+06
#
#    (TRACI (2.1) SwolfPy, environmental impact, eutrophication)  \
# 0 -393274.23
# 1 -416617.07
# 2 -158424.33
# 3 -511993.34
# 4 -520696.50
#
#    (TRACI (2.1) SwolfPy, environmental impact, photochemical smog)  \
# 0 -3.29e+06
# 1 -3.51e+06
# 2  6.98e+05
# 3 -5.74e+06
# 4 -5.68e+06
#
#    (USEtox (obsolete), ecotoxicity, total)  \
# 0 -2.55e+09
# 1 -2.58e+09
# 2 -2.39e+09
# 3 -2.64e+09
# 4 -2.65e+09
#
#    (USEtox (obsolete), human toxicity, total)  \
# 0 -101.15
# 1 -103.00
# 2 -87.12
# 3 -108.60
# 4 -109.88
#
#    (LF, Landfill operation parameteres, annWaste)  \
# 0  147690.88
# 1  227156.51
# 2  168224.39
# 3  184519.03
# 4  177826.77
#
#    (LF, Landfill operation parameteres, optime)  \
# 0  149.85
# 1  49.55
# 2  37.64
# 3  40.60
# 4  29.85
#
#    (LF, Landfill Gas Parameters, actk)  \
# 0  0.04
# 1  0.08
# 2  0.05
# 3  0.08
# 4  0.06
#
#    (LF, Landfill Gas Parameters, initColEff)  \
# 0  47.81
# 1  53.53
# 2  55.59
# 3  56.68
# 4  47.12
#
#    (LF, Landfill Gas Parameters, intColEff)  \
# 0  68.74
# 1  75.05
# 2  68.42
# 3  73.15
# 4  75.71
#
#    (LF, Landfill Gas Parameters, incColEff)  \
# 0  84.83
# 1  87.86
# 2  81.12
# 3  81.78
# 4  81.54
#
#    (LF, Landfill Gas Parameters, finColEff)  (LF, Energy_Rec, convEff)  \
# 0  85.16                                     0.36
# 1  90.38                                     0.38
# 2  89.80                                     0.42
# 3  93.30                                     0.38
# 4  92.07                                     0.39
#
#    (LF, Operational_Cost, Yard_Trimmings_Leaves)  \
# 0  20.54
# 1  15.48
# 2  17.05
# 3  9.81
# 4  17.90
#
#    (LF, Operational_Cost, Yard_Trimmings_Grass)  \
# 0  15.31
# 1  11.76
# 2  12.97
# 3  16.82
# 4  20.01
#
#    (LF, Operational_Cost, Yard_Trimmings_Branches)  \
# 0  17.67
# 1  25.03
# 2  16.43
# 3  23.32
# 4  15.82
#
#    (LF, Operational_Cost, Food_Waste_Vegetable)  \
# 0  16.08
# 1  21.09
# 2  16.92
# 3  15.40
# 4  20.92
#
#    (LF, Operational_Cost, Food_Waste_Non_Vegetable)  \
# 0  17.26
# 1  18.86
# 2  29.37
# 3  25.92
# 4  29.37
#
#    (LF, Operational_Cost, Wood)  (LF, Operational_Cost, Wood_Other)  \
# 0  9.60                          11.90
# 1  11.20                         17.18
# 2  18.59                         14.32
# 3  12.88                         11.01
# 4  11.63                         11.23
#
#    (LF, Operational_Cost, Textiles)  (LF, Operational_Cost, Rubber_Leather)  \
# 0  27.86                             15.05
# 1  22.93                             14.90
# 2  22.78                             12.74
# 3  22.24                             9.09
# 4  14.07                             11.46
#
#    (LF, Operational_Cost, Newsprint)  (LF, Operational_Cost, Corr_Cardboard)  \
# 0  22.18                              24.11
# 1  16.82                              21.03
# 2  14.02                              19.33
# 3  18.40                              25.85
# 4  16.43                              24.49
#
#    (LF, Operational_Cost, Office_Paper)  (LF, Operational_Cost, Magazines)  \
# 0  30.92                                 15.17
# 1  40.56                                 17.26
# 2  35.87                                 19.34
# 3  26.01                                 20.77
# 4  23.49                                 23.56
#
#    (LF, Operational_Cost, Third_Class_Mail)  \
# 0  13.85
# 1  23.50
# 2  20.89
# 3  17.78
# 4  22.83
#
#    (LF, Operational_Cost, Folding_Containers)  \
# 0  16.07
# 1  23.57
# 2  36.42
# 3  26.38
# 4  19.22
#
#    (LF, Operational_Cost, Paper_Bags)  (LF, Operational_Cost, Mixed_Paper)  \
# 0  25.08                               24.42
# 1  20.88                               27.11
# 2  28.43                               22.78
# 3  23.15                               16.43
# 4  22.29                               14.97
#
#    (LF, Operational_Cost, Paper_Non_recyclable)  \
# 0  33.90
# 1  23.33
# 2  19.74
# 3  19.66
# 4  16.19
#
#    (LF, Operational_Cost, HDPE_Translucent_Containers)  \
# 0  11.30
# 1  12.91
# 2  14.15
# 3  12.54
# 4  12.96
#
#    (LF, Operational_Cost, HDPE_Pigmented_Containers)  \
# 0  9.68
# 1  12.82
# 2  10.14
# 3  10.78
# 4  12.54
#
#    (LF, Operational_Cost, PET_Containers)  \
# 0  12.78
# 1  10.95
# 2  14.11
# 3  11.98
# 4  10.84
#
#    (LF, Operational_Cost, Plastic_Other_1_Polypropylene)  \
# 0  16.75
# 1  9.84
# 2  9.13
# 3  11.54
# 4  11.71
#
#    (LF, Operational_Cost, Plastic_Other_2)  \
# 0  12.75
# 1  12.72
# 2  14.29
# 3  10.31
# 4  10.15
#
#    (LF, Operational_Cost, Mixed_Plastic)  \
# 0  14.31
# 1  10.63
# 2  9.31
# 3  14.74
# 4  12.45
#
#    (LF, Operational_Cost, Plastic_Film)  \
# 0  17.10
# 1  11.70
# 2  10.84
# 3  9.36
# 4  14.12
#
#    (LF, Operational_Cost, Plastic_Non_Recyclable)  \
# 0  14.23
# 1  11.93
# 2  17.29
# 3  10.65
# 4  13.77
#
#    (LF, Operational_Cost, Ferrous_Cans)  \
# 0  11.42
# 1  12.50
# 2  15.83
# 3  17.31
# 4  10.72
#
#    (LF, Operational_Cost, Ferrous_Metal_Other)  \
# 0  11.53
# 1  10.37
# 2  17.10
# 3  14.23
# 4  9.74
#
#    (LF, Operational_Cost, Aluminum_Cans)  \
# 0  18.43
# 1  9.29
# 2  17.36
# 3  9.48
# 4  11.54
#
#    (LF, Operational_Cost, Aluminum_Foil)  \
# 0  12.11
# 1  10.29
# 2  9.91
# 3  9.21
# 4  11.73
#
#    (LF, Operational_Cost, Aluminum_Other)  \
# 0  10.15
# 1  9.19
# 2  11.42
# 3  10.25
# 4  11.22
#
#    (LF, Operational_Cost, Ferrous_Non_recyclable)  \
# 0  13.71
# 1  10.00
# 2  11.16
# 3  9.64
# 4  18.49
#
#    (LF, Operational_Cost, Al_Non_recyclable)  \
# 0  12.06
# 1  8.33
# 2  13.82
# 3  8.64
# 4  11.67
#
#    (LF, Operational_Cost, Glass_Brown)  (LF, Operational_Cost, Glass_Green)  \
# 0  12.86                                12.58
# 1  12.20                                10.86
# 2  14.23                                11.41
# 3  14.93                                12.54
# 4  9.72                                 10.98
#
#    (LF, Operational_Cost, Glass_Clear)  (LF, Operational_Cost, Mixed_Glass)  \
# 0  15.87                                12.53
# 1  8.50                                 9.82
# 2  13.31                                12.69
# 3  14.15                                13.97
# 4  10.73                                8.65
#
#    (LF, Operational_Cost, Glass_Non_recyclable)  \
# 0  9.92
# 1  11.89
# 2  9.45
# 3  10.33
# 4  11.92
#
#    (LF, Operational_Cost, Misc_Organic)  \
# 0  13.50
# 1  26.02
# 2  23.87
# 3  18.29
# 4  23.21
#
#    (LF, Operational_Cost, Misc_Inorganic)  (LF, Operational_Cost, E_waste)  \
# 0  13.41                                   13.99
# 1  12.08                                   14.78
# 2  15.35                                   10.24
# 3  13.49                                   10.02
# 4  12.33                                   10.44
#
#    (LF, Operational_Cost, Bottom_Ash)  (LF, Operational_Cost, Fly_Ash)  \
# 0  15.74                               11.34
# 1  10.95                               10.48
# 2  17.25                               12.77
# 3  13.94                               8.94
# 4  12.70                               12.79
#
#    (LF, Operational_Cost, Diapers_and_sanitary_products)  \
# 0  28.19
# 1  33.52
# 2  26.00
# 3  48.10
# 4  34.64
#
#    (Composting, Material_Properties, densFC)  \
# 0  636.30
# 1  718.52
# 2  585.57
# 3  829.32
# 4  679.66
#
#    (Composting, Economic_parameters, Unit_capital_cost)  \
# 0  43.39
# 1  44.98
# 2  36.01
# 3  46.89
# 4  73.57
#
#    (Composting, Operational_Cost, Yard_Trimmings_Leaves)  \
# 0  15.36
# 1  16.25
# 2  19.70
# 3  17.38
# 4  14.74
#
#    (Composting, Operational_Cost, Yard_Trimmings_Grass)  \
# 0  20.02
# 1  28.77
# 2  26.20
# 3  23.31
# 4  18.46
#
#    (Composting, Operational_Cost, Yard_Trimmings_Branches)  \
# 0  24.13
# 1  27.11
# 2  25.33
# 3  31.01
# 4  31.81
#
#    (Composting, Operational_Cost, Food_Waste_Vegetable)  \
# 0  26.65
# 1  16.00
# 2  20.53
# 3  25.02
# 4  21.32
#
#    (Composting, Operational_Cost, Food_Waste_Non_Vegetable)  \
# 0  23.50
# 1  25.38
# 2  34.81
# 3  41.82
# 4  21.07
#
#    (Composting, Operational_Cost, Wood)  \
# 0  27.40
# 1  35.43
# 2  24.54
# 3  20.63
# 4  16.45
#
#    (Composting, Operational_Cost, Wood_Other)  \
# 0  21.14
# 1  27.00
# 2  33.91
# 3  15.66
# 4  27.26
#
#    (Composting, Operational_Cost, Textiles)  \
# 0  15.78
# 1  21.76
# 2  23.93
# 3  22.38
# 4  17.13
#
#    (Composting, Operational_Cost, Rubber_Leather)  \
# 0  25.03
# 1  22.37
# 2  15.75
# 3  19.00
# 4  17.15
#
#    (Composting, Operational_Cost, Newsprint)  \
# 0  17.18
# 1  18.80
# 2  27.21
# 3  32.59
# 4  26.04
#
#    (Composting, Operational_Cost, Corr_Cardboard)  \
# 0  19.61
# 1  18.88
# 2  21.03
# 3  18.70
# 4  20.17
#
#    (Composting, Operational_Cost, Office_Paper)  \
# 0  15.07
# 1  19.56
# 2  14.83
# 3  19.01
# 4  26.04
#
#    (Composting, Operational_Cost, Magazines)  \
# 0  19.99
# 1  20.70
# 2  22.67
# 3  18.23
# 4  21.09
#
#    (Composting, Operational_Cost, Third_Class_Mail)  \
# 0  27.04
# 1  20.19
# 2  18.71
# 3  25.32
# 4  26.50
#
#    (Composting, Operational_Cost, Folding_Containers)  \
# 0  22.95
# 1  20.26
# 2  17.54
# 3  18.68
# 4  20.23
#
#    (Composting, Operational_Cost, Paper_Bags)  \
# 0  19.04
# 1  17.30
# 2  15.47
# 3  22.67
# 4  15.50
#
#    (Composting, Operational_Cost, Mixed_Paper)  \
# 0  16.45
# 1  21.18
# 2  21.93
# 3  18.43
# 4  32.06
#
#    (Composting, Operational_Cost, Paper_Non_recyclable)  \
# 0  17.10
# 1  20.34
# 2  23.26
# 3  15.39
# 4  17.80
#
#    (Composting, Operational_Cost, HDPE_Translucent_Containers)  \
# 0  24.08
# 1  16.47
# 2  16.75
# 3  17.84
# 4  18.22
#
#    (Composting, Operational_Cost, HDPE_Pigmented_Containers)  \
# 0  18.98
# 1  22.80
# 2  15.02
# 3  19.13
# 4  24.67
#
#    (Composting, Operational_Cost, PET_Containers)  \
# 0  27.38
# 1  29.51
# 2  18.34
# 3  17.40
# 4  15.31
#
#    (Composting, Operational_Cost, Plastic_Other_1_Polypropylene)  \
# 0  21.95
# 1  24.00
# 2  16.54
# 3  21.18
# 4  19.45
#
#    (Composting, Operational_Cost, Plastic_Other_2)  \
# 0  17.56
# 1  24.63
# 2  22.11
# 3  21.33
# 4  22.84
#
#    (Composting, Operational_Cost, Mixed_Plastic)  \
# 0  30.13
# 1  22.62
# 2  20.20
# 3  25.56
# 4  21.30
#
#    (Composting, Operational_Cost, Plastic_Film)  \
# 0  20.00
# 1  22.77
# 2  24.19
# 3  21.42
# 4  24.88
#
#    (Composting, Operational_Cost, Plastic_Non_Recyclable)  \
# 0  26.42
# 1  23.60
# 2  20.74
# 3  26.44
# 4  23.50
#
#    (Composting, Operational_Cost, Ferrous_Cans)  \
# 0  13.61
# 1  20.10
# 2  21.76
# 3  25.06
# 4  21.26
#
#    (Composting, Operational_Cost, Ferrous_Metal_Other)  \
# 0  30.58
# 1  17.17
# 2  19.06
# 3  23.98
# 4  27.21
#
#    (Composting, Operational_Cost, Aluminum_Cans)  \
# 0  18.52
# 1  20.11
# 2  24.79
# 3  22.16
# 4  23.21
#
#    (Composting, Operational_Cost, Aluminum_Foil)  \
# 0  23.22
# 1  20.89
# 2  19.92
# 3  22.13
# 4  31.88
#
#    (Composting, Operational_Cost, Aluminum_Other)  \
# 0  19.10
# 1  32.85
# 2  19.00
# 3  21.79
# 4  19.08
#
#    (Composting, Operational_Cost, Ferrous_Non_recyclable)  \
# 0  20.52
# 1  24.26
# 2  27.56
# 3  24.41
# 4  26.94
#
#    (Composting, Operational_Cost, Al_Non_recyclable)  \
# 0  17.32
# 1  27.07
# 2  25.56
# 3  21.66
# 4  16.54
#
#    (Composting, Operational_Cost, Glass_Brown)  \
# 0  14.27
# 1  25.96
# 2  24.27
# 3  24.71
# 4  15.57
#
#    (Composting, Operational_Cost, Glass_Green)  \
# 0  20.20
# 1  22.82
# 2  17.31
# 3  20.25
# 4  24.31
#
#    (Composting, Operational_Cost, Glass_Clear)  \
# 0  19.97
# 1  25.75
# 2  22.31
# 3  13.25
# 4  23.46
#
#    (Composting, Operational_Cost, Mixed_Glass)  \
# 0  27.05
# 1  18.54
# 2  25.00
# 3  26.54
# 4  25.36
#
#    (Composting, Operational_Cost, Glass_Non_recyclable)  \
# 0  28.89
# 1  25.51
# 2  23.38
# 3  22.59
# 4  24.60
#
#    (Composting, Operational_Cost, Misc_Organic)  \
# 0  16.11
# 1  25.78
# 2  16.58
# 3  31.08
# 4  24.73
#
#    (Composting, Operational_Cost, Misc_Inorganic)  \
# 0  10.34
# 1  11.86
# 2  10.15
# 3  11.69
# 4  9.88
#
#    (Composting, Operational_Cost, E_waste)  \
# 0  24.20
# 1  21.22
# 2  22.94
# 3  21.03
# 4  31.85
#
#    (Composting, Operational_Cost, Bottom_Ash)  \
# 0  3.45
# 1  3.88
# 2  4.14
# 3  4.04
# 4  4.85
#
#    (Composting, Operational_Cost, Fly_Ash)  \
# 0  4.93
# 1  3.08
# 2  4.09
# 3  4.33
# 4  3.29
#
#    (Composting, Operational_Cost, Diapers_and_sanitary_products)  \
# 0  11.39
# 1  14.33
# 2  12.51
# 3  12.47
# 4  9.80
#
#    (Home Composting, Material_Properties, densFC)  \
# 0  694.37
# 1  864.03
# 2  615.83
# 3  575.47
# 4  609.10
#
#    (Home Composting, Economic_parameters, comp_cost)  \
# 0  92.00
# 1  65.23
# 2  69.86
# 3  110.58
# 4  80.93
#
#    (AD, Biogas_gen, ad_HeatRate)  (AD, Material_Properties, densFC)  \
# 0  9.51                           641.14
# 1  10.01                          604.00
# 2  9.50                           532.44
# 3  9.97                           597.96
# 4  10.98                          743.50
#
#    (AD, Economic_parameters, Unit_capital_cost)  \
# 0  580.33
# 1  648.91
# 2  875.86
# 3  497.14
# 4  996.60
#
#    (AD, Operational_Cost, Yard_Trimmings_Leaves)  \
# 0  36.89
# 1  40.38
# 2  32.49
# 3  21.14
# 4  24.36
#
#    (AD, Operational_Cost, Yard_Trimmings_Grass)  \
# 0  13.11
# 1  16.48
# 2  10.10
# 3  15.33
# 4  10.79
#
#    (AD, Operational_Cost, Yard_Trimmings_Branches)  \
# 0  24.64
# 1  28.03
# 2  27.71
# 3  20.54
# 4  26.77
#
#    (AD, Operational_Cost, Food_Waste_Vegetable)  \
# 0  9.27
# 1  12.37
# 2  9.30
# 3  11.64
# 4  13.44
#
#    (AD, Operational_Cost, Food_Waste_Non_Vegetable)  \
# 0  14.85
# 1  17.68
# 2  10.97
# 3  18.48
# 4  15.62
#
#    (AD, Operational_Cost, Wood)  (AD, Operational_Cost, Wood_Other)  \
# 0  37.32                         47.77
# 1  33.80                         24.34
# 2  33.64                         34.07
# 3  28.25                         29.52
# 4  34.79                         30.66
#
#    (AD, Operational_Cost, Textiles)  (AD, Operational_Cost, Rubber_Leather)  \
# 0  29.94                             24.81
# 1  25.80                             31.23
# 2  35.86                             41.75
# 3  33.07                             23.42
# 4  32.83                             39.95
#
#    (AD, Operational_Cost, Newsprint)  (AD, Operational_Cost, Corr_Cardboard)  \
# 0  29.38                              19.20
# 1  36.19                              35.22
# 2  30.31                              26.88
# 3  24.94                              24.33
# 4  30.30                              43.17
#
#    (AD, Operational_Cost, Office_Paper)  (AD, Operational_Cost, Magazines)  \
# 0  25.11                                 27.69
# 1  25.54                                 34.98
# 2  29.20                                 49.79
# 3  29.36                                 41.83
# 4  29.21                                 47.96
#
#    (AD, Operational_Cost, Third_Class_Mail)  \
# 0  42.20
# 1  42.58
# 2  39.67
# 3  38.25
# 4  19.70
#
#    (AD, Operational_Cost, Folding_Containers)  \
# 0  29.26
# 1  29.90
# 2  27.08
# 3  42.46
# 4  30.16
#
#    (AD, Operational_Cost, Paper_Bags)  (AD, Operational_Cost, Mixed_Paper)  \
# 0  21.33                               36.26
# 1  24.71                               17.78
# 2  33.00                               28.95
# 3  33.91                               28.76
# 4  33.02                               30.04
#
#    (AD, Operational_Cost, Paper_Non_recyclable)  \
# 0  25.12
# 1  22.21
# 2  24.61
# 3  26.32
# 4  33.57
#
#    (AD, Operational_Cost, HDPE_Translucent_Containers)  \
# 0  8.53
# 1  6.63
# 2  8.97
# 3  13.90
# 4  11.93
#
#    (AD, Operational_Cost, HDPE_Pigmented_Containers)  \
# 0  6.35
# 1  10.75
# 2  8.01
# 3  7.30
# 4  7.40
#
#    (AD, Operational_Cost, PET_Containers)  \
# 0  7.81
# 1  8.88
# 2  8.97
# 3  7.72
# 4  7.53
#
#    (AD, Operational_Cost, Plastic_Other_1_Polypropylene)  \
# 0  6.06
# 1  7.22
# 2  7.95
# 3  8.03
# 4  10.86
#
#    (AD, Operational_Cost, Plastic_Other_2)  \
# 0  7.87
# 1  9.86
# 2  7.83
# 3  9.63
# 4  8.11
#
#    (AD, Operational_Cost, Mixed_Plastic)  \
# 0  8.04
# 1  10.23
# 2  9.74
# 3  7.94
# 4  8.94
#
#    (AD, Operational_Cost, Plastic_Film)  \
# 0  11.55
# 1  8.12
# 2  7.20
# 3  8.22
# 4  9.19
#
#    (AD, Operational_Cost, Plastic_Non_Recyclable)  \
# 0  7.63
# 1  10.23
# 2  12.62
# 3  8.92
# 4  8.61
#
#    (AD, Operational_Cost, Ferrous_Cans)  \
# 0  8.02
# 1  6.47
# 2  7.96
# 3  8.93
# 4  12.04
#
#    (AD, Operational_Cost, Ferrous_Metal_Other)  \
# 0  5.57
# 1  9.91
# 2  6.82
# 3  7.01
# 4  5.94
#
#    (AD, Operational_Cost, Aluminum_Cans)  \
# 0  8.33
# 1  7.75
# 2  9.36
# 3  10.48
# 4  7.27
#
#    (AD, Operational_Cost, Aluminum_Foil)  \
# 0  8.72
# 1  5.10
# 2  7.82
# 3  8.20
# 4  7.15
#
#    (AD, Operational_Cost, Aluminum_Other)  \
# 0  7.05
# 1  10.77
# 2  6.17
# 3  9.45
# 4  6.84
#
#    (AD, Operational_Cost, Ferrous_Non_recyclable)  \
# 0  7.35
# 1  9.58
# 2  9.06
# 3  6.81
# 4  10.28
#
#    (AD, Operational_Cost, Al_Non_recyclable)  \
# 0  6.31
# 1  6.46
# 2  6.96
# 3  8.11
# 4  8.64
#
#    (AD, Operational_Cost, Glass_Brown)  (AD, Operational_Cost, Glass_Green)  \
# 0  9.82                                 9.85
# 1  7.30                                 5.63
# 2  8.48                                 7.43
# 3  6.45                                 8.36
# 4  7.41                                 7.74
#
#    (AD, Operational_Cost, Glass_Clear)  (AD, Operational_Cost, Mixed_Glass)  \
# 0  11.42                                8.25
# 1  10.00                                10.66
# 2  7.01                                 9.29
# 3  8.12                                 8.89
# 4  8.36                                 8.14
#
#    (AD, Operational_Cost, Glass_Non_recyclable)  \
# 0  7.51
# 1  7.82
# 2  8.67
# 3  7.04
# 4  8.97
#
#    (AD, Operational_Cost, Misc_Organic)  \
# 0  26.06
# 1  41.44
# 2  26.21
# 3  28.86
# 4  33.89
#
#    (AD, Operational_Cost, Misc_Inorganic)  (AD, Operational_Cost, E_waste)  \
# 0  6.17                                    6.39
# 1  7.93                                    5.73
# 2  8.89                                    10.64
# 3  6.56                                    10.30
# 4  7.53                                    8.16
#
#    (AD, Operational_Cost, Bottom_Ash)  (AD, Operational_Cost, Fly_Ash)  \
# 0  49.46                               33.11
# 1  41.88                               48.64
# 2  37.39                               34.39
# 3  49.61                               40.06
# 4  51.12                               37.07
#
#    (AD, Operational_Cost, Diapers_and_sanitary_products)  \
# 0  22.33
# 1  22.69
# 2  22.65
# 3  20.76
# 4  23.81
#
#    (Animal Feed, AnF_operation, FeedSubFac)  \
# 0  0.97
# 1  0.96
# 2  0.81
# 3  0.80
# 4  0.72
#
#    (Animal Feed, Equipment:Conveyor, motor)  \
# 0  6.19
# 1  4.26
# 2  5.04
# 3  6.02
# 4  4.97
#
#    (Animal Feed, Equipment:Conveyor, Investment_cost)  \
# 0  49436.30
# 1  57001.40
# 2  42920.32
# 3  38999.24
# 4  34166.77
#
#    (Animal Feed, Equipment:Conveyor, Installation_cost)  \
# 0  3369.40
# 1  4396.78
# 2  6931.88
# 3  4186.99
# 4  4799.47
#
#    (Animal Feed, Equipment:Conveyor, O&M)  \
# 0  8784.98
# 1  11866.73
# 2  8931.73
# 3  10839.11
# 4  9228.99
#
#    (Animal Feed, Equipment:Drum Feeder, motor)  \
# 0  16.09
# 1  12.84
# 2  16.65
# 3  18.07
# 4  11.25
#
#    (Animal Feed, Equipment:Drum Feeder, Investment_cost)  \
# 0  151447.12
# 1  151374.22
# ...
#
#    (RDF, Equipment:Baler, Investment_cost)  \
# 0  737316.28
# 1  706642.52
# 2  584409.59
# 3  605417.16
# 4  643869.22
#
#    (RDF, Equipment:Baler, Installation_cost)  (RDF, Equipment:Baler, O&M)  \
# 0  49051.16                                   7502.62
# 1  50792.33                                   5343.24
# 2  64272.51                                   5291.84
# 3  57246.66                                   5309.91
# 4  57374.78                                   6319.98
#
#    (RDF, Equipment:Optical Sorter, motor)  \
# 0  48.36
# 1  46.64
# 2  57.10
# 3  70.44
# 4  72.40
#
#    (RDF, Equipment:Optical Sorter, Investment_cost)  \
# 0  9.18e+05
# 1  7.77e+05
# 2  8.89e+05
# 3  1.02e+06
# 4  6.52e+05
#
#    (RDF, Equipment:Optical Sorter, Installation_cost)  \
# 0  54593.53
# 1  106930.10
# 2  71563.68
# 3  70197.93
# 4  106744.59
#
#    (RDF, Equipment:Optical Sorter, O&M)  \
# 0  2627.89
# 1  4073.60
# 2  3312.94
# 3  1989.90
# 4  2667.01
#
#    (RDF, Equipment:Densimetric table, motor)  \
# 0  14.91
# 1  12.41
# 2  11.93
# 3  12.98
# 4  12.14
#
#    (RDF, Equipment:Densimetric table, Investment_cost)  \
# 0  107527.46
# 1  196429.41
# 2  91936.05
# 3  93691.27
# 4  151937.65
#
#    (RDF, Equipment:Densimetric table, Installation_cost)  \
# 0  8882.30
# 1  14872.84
# 2  12536.27
# 3  9554.41
# 4  11382.73
#
#    (RDF, Equipment:Densimetric table, O&M)  \
# 0  6972.44
# 1  9338.65
# 2  6985.63
# 3  9302.20
# 4  8193.83
#
#    (RDF, Equipment:Rolling Stock, diesel_use)  \
# 0  10.49
# 1  11.02
# 2  11.64
# 3  7.97
# 4  10.78
#
#    (RDF, Equipment:Rolling Stock, Investment_cost)  \
# 0  350144.62
# 1  343428.20
# 2  371628.55
# 3  384983.58
# 4  352752.57
#
#    (RDF, Equipment:Rolling Stock, O&M)  \
# 0  5032.93
# 1  4699.91
# 2  7049.69
# 3  5429.23
# 4  5498.80
#
#    (Gasification Syngas Combustion, Energy, elec_gen_eff_HP)  \
# 0  0.28
# 1  0.35
# 2  0.12
# 3  0.41
# 4  0.43
#
#    (Gasification Syngas Combustion, Energy, elec_gen_eff_MP)  \
# 0  0.20
# 1  0.24
# 2  0.22
# 3  0.20
# 4  0.22
#
#    (Gasification Syngas Combustion, Energy, frac_lhv_internal_elec)  \
# 0  0.03
# 1  0.07
# 2  0.04
# 3  0.05
# 4  0.07
#
#    (Gasification Syngas Combustion, Economic_params, capital_cost)  \
# 0  746.34
# 1  485.25
# 2  880.25
# 3  575.56
# 4  575.48
#
#    (Gasification Syngas Combustion, Economic_params, O&M_cost)  \
# 0  71.29
# 1  120.58
# 2  55.25
# 3  63.32
# 4  69.09
#
#    (WTE, Economic_parameters, Capital_cost)  \
# 0  490.74
# 1  392.66
# 2  736.46
# 3  705.90
# 4  523.33
#
#    (WTE, Economic_parameters, O_M_cost)  \
# 0  40.01
# 1  36.88
# 2  45.42
# 3  33.70
# 4  45.78
#
#    (WTE, Elec_Prod_Eff, Gross_Efficiency)  (WTE, Elec_Prod_Eff, Internal_use)  \
# 0  0.14                                    0.13
# 1  0.20                                    0.14
# 2  0.26                                    0.16
# 3  0.24                                    0.17
# 4  0.39                                    0.17
#
#    (WTE, Metals_Recovery, Al_Rec_Rate)  (SF, Speed, Vbet)  (SF, Speed, Vrf)  \
# 0  0.90                                 12.11              55.05
# 1  0.89                                 10.08              70.71
# 2  0.94                                 7.30               51.15
# 3  0.93                                 10.37              64.89
# 4  0.92                                 13.39              76.61
#
#    (SF, Speed, Vgr)  (SF, Speed, Vfg)  (SF, LCC, a)  (SF, LCC, d)  \
# 0  38.17             43.82             0.47          12774.67
# 1  39.94             51.39             0.43          13123.49
# 2  37.31             40.68             0.35          14933.37
# 3  35.83             51.84             0.47          11000.53
# 4  33.43             71.90             0.48          14862.85
#
#    (SF, LCC, e)  (SF, LCC, Wa)  (SF, LCC, Wd)  (SF, LCC, Pt)  (SF, LCC, c)  \
# 0  0.10          14.67          14.97          176189.28      46151.77
# 1  0.12          16.84          13.64          246455.29      35838.32
# 2  0.11          12.75          13.05          300785.07      36180.98
# 3  0.14          14.94          12.90          237046.55      42004.98
# 4  0.13          17.09          24.56          307317.06      30716.19
#
#    (SF, LCC, Pb)  (SF, TL, RWC)  (SF, TL, SSR)  (SF, TL, DSR)  (SF, TL, MSR)  \
# 0  9.91           0.24           0.16           0.55           0.47
# 1  7.19           0.18           0.16           0.41           0.38
# 2  7.25           0.21           0.18           0.55           0.48
# 3  9.47           0.13           0.16           0.49           0.44
# 4  6.77           0.15           0.17           0.48           0.35
#
#    (SF, TL, LV)  (SF, TL, SSYW)  (SF, TL, SSO)  (SF, TL, ORG)  (SF, TL, REC)  \
# 0  0.16          0.21            0.20           0.36           0.43
# 1  0.14          0.18            0.20           0.44           0.44
# 2  0.25          0.13            0.22           0.38           0.47
# 3  0.14          0.14            0.23           0.38           0.48
# 4  0.14          0.24            0.19           0.60           0.48
#
#    (SF, S, RWC)  (SF, S, SSR)  (SF, S, DSR)  (SF, S, MSR)  (SF, S, LV)  \
# 0  10.77         11.29         21.09         32.22         20.03
# 1  15.92         16.95         17.95         23.04         18.94
# 2  23.80         22.68         13.80         19.13         15.79
# 3  16.97         14.56         32.35         17.25         15.03
# 4  15.11         12.19         19.81         18.17         17.26
#
#    (SF, S, SSYW)  (SF, S, SSO)  (SF, S, ORG)  (SF, S, REC)  (MF, Speed, Vbet)  \
# 0  22.36          16.32         42.32         30.90         8.18
# 1  16.66          25.83         38.44         27.64         6.61
# 2  10.45          15.84         34.62         31.23         7.62
# 3  14.92          14.66         32.92         21.65         11.65
# 4  22.10          12.78         29.61         36.57         9.28
#
#    (MF, Speed, Vrf)  (MF, Speed, Vgr)  (MF, Speed, Vfg)  (MF, LCC, a)  \
# 0  46.07             28.28             59.83             0.35
# 1  72.81             37.14             55.70             0.36
# 2  84.66             34.50             46.93             0.37
# 3  52.30             31.52             53.58             0.49
# 4  63.04             34.38             60.99             0.48
#
#    (MF, LCC, d)  (MF, LCC, e)  (MF, LCC, Wa)  (MF, LCC, Wd)  (MF, LCC, Pt)  \
# 0  11440.36      0.07          12.94          14.07          215575.90
# 1  11690.11      0.12          11.76          14.45          222412.03
# 2  12415.37      0.10          12.60          16.20          175061.98
# 3  14442.63      0.10          11.30          13.64          283355.14
# 4  12024.53      0.08          8.60           17.84          227749.58
#
#    (MF, LCC, c)  (MF, TL, RWC)  (MF, TL, SSR)  (MF, TL, DSR)  (MF, TL, MSR)  \
# 0  42604.50      1.15           1.16           1.01           0.80
# 1  40718.19      1.30           1.11           1.24           0.97
# 2  51990.87      0.90           1.15           0.68           0.92
# 3  33656.59      0.82           1.43           0.99           1.19
# 4  44910.59      0.74           0.95           0.82           1.44
#
#    (MF, TL, SSYW)  (MF, TL, SSO)  (MF, TL, ORG)  (MF, TL, REC)  (MF, S, RWC)  \
# 0  1.16            1.37           0.99           0.87           19.92
# 1  1.02            1.24           0.81           1.04           16.38
# 2  1.11            1.10           1.13           1.08           20.94
# 3  0.78            1.25           1.09           1.19           16.23
# 4  0.80            1.00           0.92           0.97           22.30
#
#    (MF, S, SSR)  (MF, S, DSR)  (MF, S, MSR)  (MF, S, SSYW)  (MF, S, SSO)  \
# 0  15.04         23.12         27.26         18.15          14.52
# 1  11.42         15.78         22.55         18.39          14.26
# 2  19.60         22.53         17.45         13.87          20.38
# 3  11.53         17.57         23.55         16.12          23.15
# 4  17.26         18.23         20.62         18.65          23.55
#
#    (MF, S, ORG)  (MF, S, REC)  (COM, Speed, Vbet)  (COM, Speed, Vrf)  \
# 0  35.80         45.41         7.50                53.69
# 1  30.52         28.14         8.80                45.06
# 2  43.73         34.63         12.48               57.51
# 3  32.46         22.22         8.56                58.08
# 4  33.43         49.71         12.62               52.36
#
#    (COM, Speed, Vgr)  (COM, Speed, Vfg)  (COM, LCC, a)  (COM, LCC, d)  \
# 0  29.78              39.29              0.51           10570.60
# 1  30.34              54.44              0.40           10899.11
# 2  25.78              79.29              0.46           11771.65
# 3  28.83              70.37              0.47           11035.22
# 4  30.65              32.57              0.35           14695.06
#
#    (COM, LCC, e)  (COM, LCC, Wa)  (COM, LCC, Wd)  (COM, LCC, Pt)  \
# 0  0.13           9.22            17.44           176565.98
# 1  0.12           13.53           13.89           228116.88
# 2  0.14           13.92           14.75           274843.03
# 3  0.13           11.97           11.66           209110.58
# 4  0.09           10.04           20.34           321505.74
#
#    (COM, LCC, c)  (COM, TL, RWC)  (COM, TL, SSR)  (COM, TL, DSR)  \
# 0  40041.04       1.78            0.89            1.10
# 1  40590.33       1.01            0.87            0.89
# 2  44705.28       1.23            0.79            0.82
# 3  46965.14       1.19            0.75            0.90
# 4  40302.38       1.07            0.91            0.74
#
#    (COM, TL, MSR)  (COM, TL, SSYW)  (COM, TL, SSO)  (COM, TL, SSO_AnF)  \
# 0  1.25            0.78             1.31            0.98
# 1  0.98            1.31             1.07            0.93
# 2  0.98            1.11             1.33            0.71
# 3  1.04            0.76             0.79            1.00
# 4  0.86            1.05             0.73            0.82
#
#    (COM, TL, ORG)  (COM, TL, REC)  (COM, S, RWC)  (COM, S, SSR)  \
# 0  0.64            1.22            13.02          11.19
# 1  0.87            0.89            25.05          16.52
# 2  0.66            1.34            14.59          13.10
# 3  0.88            0.98            14.29          17.51
# 4  1.14            1.02            16.58          18.55
#
#    (COM, S, DSR)  (COM, S, MSR)  (COM, S, SSYW)  (COM, S, SSO)  \
# 0  25.47          22.11          16.45           18.19
# 1  10.66          22.26          16.76           19.03
# 2  19.21          17.84          14.18           12.24
# 3  16.04          17.10          29.40           14.12
# 4  20.13          29.44          12.94           13.82
#
#    (COM, S, SSO_AnF)  (COM, S, ORG)  (COM, S, REC)
# 0  17.78              25.40          20.55
# 1  12.72              48.84          39.09
# 2  11.41              30.75          33.69
# 3  21.62              28.45          42.05
# 4  18.94              39.69          35.07

# %%
FU = bw2.get_activity(('waste', 'Collection'))
fig, axes = plt.subplots(5, 2, figsize=(12, 12))


lables = ['GWP', 'Total Cost', 'Operational Cost', 'Capital Cost',
          'CED', 'Acidification', 'Eutrophication', 'Smog',
          'ETOX', 'HTOX']

r = 0
c = 0
for m in [ GWP_Method, TotCost_Method, OptCost_Method, CapCost_Method,
           CED_Method, ACID_Method, ETP_Method, SMOG_Method, ETOX_Method,
           HTOX_Method]:
    histdata = mc_results[[m]]/float(FU.as_dict()['unit'].split(' ')[0])
    sns.histplot(data=histdata, x=histdata.columns[0], ax=axes[r][c], stat='probability')
    axes[r][c].set_xlabel(lables[c + r * 2])
    axes[r][c].set_ylabel('Percent')
    axes[r][c].xaxis.tick_bottom()
    axes[r][c].yaxis.tick_left()
    
    lca.switch_method(m)
    lca.lcia()
    axes[r][c].axvline(lca.score/float(FU.as_dict()['unit'].split(' ')[0]), c='m')
    
    axes[r][c].axvline(stats.scoreatpercentile(histdata, 2.5), c='r', label='95%\nconfidence\ninterval')
    axes[r][c].axvline(stats.scoreatpercentile(histdata, 97.5), c='r')
    c += 1
    if c==2:
        r += 1
        c = 0

fig.tight_layout()

#fig.savefig('MC_Dist',dpi=600, bbox_inches='tight')
